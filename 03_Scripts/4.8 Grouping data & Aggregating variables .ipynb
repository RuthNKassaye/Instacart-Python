# %%
# Importing libraries
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\Ruth Kassaye\Documents\CareerFoundery\DataImmersion\Achievement_4'

# %% [markdown]
# ## Directions

# %% [markdown]
# ### Q1. Create a new notebook for this task. Be sure to import the relevant libraries, along with your ords_prods_merge dataframe, which should include your newly derived columns from the previous Exercise.

# %%
# Importing orders_products_merged_coumns_added.pkl'
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_columns_added.pkl'))

# %% [markdown]
# ### Q2. In this Exercise, you learned how to find the aggregated mean of the “order_number” column grouped by “department_id” for a subset of your dataframe. Now, repeat this process for the entire dataframe.

# %%
# Grouping the average number of orders per department ID
ords_prods_merge.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                15.457838
# 2                17.277920
# 3                17.170395
# 4                17.811403
# 5                15.215751
# 6                16.439806
# 7                17.225802
# 8                15.340650
# 9                15.895474
# 10               20.197148
# 11               16.170638
# 12               15.887671
# 13               16.583536
# 14               16.773669
# 15               16.165037
# 16               17.665606
# 17               15.694469
# 18               19.310397
# 19               17.177343
# 20               16.473447
# 21               22.902379

# %% [markdown]
# ### Q3. Analyze the result. How do the results for the entire dataframe differ from those of the subset? Include your comments in a markdown cell below the executed code.

# %% [markdown]
#  - **Answer**: the subset only analyzes the first 1000000 entries, hence doesn't give a complete picture of anaysis. However, the entire dataframes takes into consideration of the entire entries

# %% [markdown]
# ### Q4. Follow the instructions in the Exercise for creating a loyalty flag for existing customers using the transform() and loc() functions.

# %% [markdown]
# #### Step 1: Grouping and aggregating: userid by order_number
#
#    1. Split the data into groups based on the “user_id” column
#    2. Apply the transform() function on the “order_number” column to generate the maximum orders for each user.
#    3. Third: Create a new column, “max_order,” into which you’ll place the results of your aggregation.

# %%
# Calling all the above 3 teps at once, to create a new column containing the maximum frequency of the “order_number” column
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id']) ['order_number'].transform(np.max)

# %%
# Calling ords_prods_merge to check if the new column max_order(that stores the maximum order number for each user)
ords_prods_merge.head(15)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# ...

# %% [markdown]
# #### Step 2: Creating a loyalty flag using loc() function based on the following criteria:
#
#    1. If the maximum orders the user has made is **over 40**, then the customer will be labeled a **“Loyal customer.”**
#    2. If the maximum orders the user has made is **over 10 but less than or equal to 40**, then the customer will be labeled a **“Regular customer.”**
#    3. If the maximum orders the user has made is **less than or equal to 10**, then the customer will be labeled a **“New customer.”**

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] >40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <=10, 'loyalty_flag'] = 'New customer'

# %%
# Calling ords_prods_merge to check the new loyalty flag column based on the above criteria 
ords_prods_merge.head(15)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# ...

# %%
# Printing frequency of the new loyalty_flag
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: loyalty_flag, dtype: int64

# %% [markdown]
# ### Q5. The marketing team at Instacart wants to know whether there’s a difference between the spending habits of the three types of customers you identified. Use the loyalty flag you created and check the basic statistics of the product prices for each loyalty category (Loyal Customer, Regular Customer, and New Customer). What you’re trying to determine is whether the prices of products purchased by loyal customers differ from those purchased by regular or new customers.

# %%
ords_prods_merge.groupby('loyalty_flag').agg({'prices':['mean', 'min', 'max']})
# Out:
#                      prices
#                        mean  min      max
# loyalty_flag
# Loyal customer    10.386335  1.0  99999.0
# New customer      13.294670  1.0  99999.0
# Regular customer  12.495717  1.0  99999.0

# %% [markdown]
# ### Q6. The team now wants to target different types of spenders in their marketing campaigns. This can be achieved by looking at the prices of the items people are buying. Create a spending flag for each user based on the average price across all their orders using the following criteria:
#
#    - If the mean of the prices of products purchased by a user is lower than 10, then flag them as a “Low spender.”
#    - If the mean of the prices of products purchased by a user is higher than or equal to 10, then flag them as a “High spender.”

# %%
# First step: creating a new column that stores mean of prices of each users
ords_prods_merge['mean_price'] = ords_prods_merge.groupby(['user_id']) ['prices'].transform(np.mean)

# %%
ords_prods_merge.head(15)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# ...

# %% [markdown]
# ##### Note: I am telling to create a spender_flag based on the criteria listed above.
#   - For example in case of the first criteria, I am telling panda to go to ords_prods_merge dataframe and check the 'mean_price' column values and if a value is less than one store it as low spender in a new column 'spender_flag'. Same logic for the last two command lines

# %%
# Second step: creating a spending flag column based on the criteria given up
ords_prods_merge.loc[ords_prods_merge['mean_price'] <10, 'spender_flag'] = 'Low spender'

# %%
ords_prods_merge.loc[ords_prods_merge['mean_price'] >=10, 'spender_flag'] = 'High spender'

# %%
ords_prods_merge.head(15)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# ...

# %% [markdown]
# ### Q7. In order to send relevant notifications to users within the app (for instance, asking users if they want to buy the same item again), the Instacart team wants you to determine frequent versus non-frequent customers. Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column. The criteria for the flag should be as follows:
#
#  - If the median of “days_since_prior_order” is higher than 20, then the customer should be labeled a “Non-frequent customer.”
#  - If the median is higher than 10 and lower than or equal to 20, then the customer should be labeled a “Regular customer.”
#  - If the median is lower than or equal to 10, then the customer should be labeled a “Frequent customer.”

# %% [markdown]
# #### First step: creating a new column that stores median of days_since_prior_order of each users

# %%
# First step: creating a new column that stores median of days_since_prior_order of each users

ords_prods_merge['median_days_since_prior_order'] = ords_prods_merge.groupby(['user_id'])['days_since_prior_order'].transform(np.median)

# %%
# Calling ords_prods_merge dataframe to check if the new median_days_since_prior_order column is created
ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                   2                  8
# 1   2398795        1             2                   3                  7
# 2    473747        1             3                   3                 12
# 3   2254736        1             4                   4                  7
# 4    431534        1             5                   4                 15
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered _merge  \
# 0                     7.0         196                  1          0   both
# 1                    15.0         196                  1          1   both
# 2                    21.0         196                  1          1   both
# 3                    29.0         196                  1          1   both
# 4                    28.0         196                  1          1   both
#
#    ... prices    price_range_loc     busiest_day    busiest_days  \
# ...

# %% [markdown]
# #### Second step:
#    - Create an order frequency flag that marks the regularity of a user’s ordering behavior according to the median in the “days_since_prior_order” column. The criteria for the flag should be as follows:¶
#
#    1. If the median of “days_since_prior_order” is **higher than 20**, then the customer should be labeled a **“Non-frequent customer.”**
#    2. If the median is **higher than 10 and lower than or equal to 20**, then the customer should be labeled a **“Regular customer.”**
#    3. If the median is **lower than or equal to 10**, then the customer should be labeled a **“Frequent customer.”**

# %%
ords_prods_merge.loc[ords_prods_merge['median_days_since_prior_order'] >20, 'frequency_flag'] = 'Non-frequent customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['median_days_since_prior_order']>10) & (ords_prods_merge['median_days_since_prior_order']<=20), 'frequency_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['median_days_since_prior_order'] <=10, 'frequency_flag'] = 'Frequent customer'

# %%
ords_prods_merge.head(15)
# Out:
#     order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0    2539329        1             1                   2                  8
# 1    2398795        1             2                   3                  7
# 2     473747        1             3                   3                 12
# 3    2254736        1             4                   4                  7
# 4     431534        1             5                   4                 15
# 5    3367565        1             6                   2                  7
# 6     550135        1             7                   1                  9
# 7    3108588        1             8                   1                 14
# 8    2295261        1             9                   1                 16
# 9    2550362        1            10                   4                  8
# 10   2968173       15            15                   1                  9
# ...

# %% [markdown]
# ### Q9. Export your dataframe as a pickle file and store it correctly in your “Prepared Data” folder.

# %%
# Exporting the df_ords_prods_merge dataframe as a pickle format
ords_prods_merge.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'orders_products_merged_grouped.pkl'))
